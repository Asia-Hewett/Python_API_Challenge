# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import pprint as pprint
from scipy.stats import linregress

from pandas.io.json import json_normalize

# Import API key
from weather_py.api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

final_url = url + "appid=" + weather_api_key + "&q=" 

# Get the temperature from the response
# print(f"The weather API responded with: {weather_json}.")
 
    
# weather_response = requests.get(final_url + cities[0])
# weather_json = weather_response.json()

pp = pprint.PrettyPrinter(indent=4, width=80, compact=False)

# Testing PPrint and jsonifying the code so I can read the key names
# pp.pprint(weather_json)
# weather_json['name']
# weather_json['id']
# print(f"name: {weather_json['name']}, city id: {weather_json['id']}")

# Error message;
# {'cod': '404', 'message': 'city not found'}

counter = 0
set_counter = 1
city_data = []


# 	City	Lat	Lng	Max Temp	Humidity	Cloudiness	Wind Speed	Country	Date

for city in cities:
    formatted_weath_json = {}
    counter += 1
    if counter == 51:
        set_counter += 1
        counter = 0
#     if counter >= 500:
# #         print(weather_json)
#         break
    final_url = url + "appid=" + weather_api_key + "&q=" + city
    
    weather_response = requests.get(final_url)
    weather_json = weather_response.json()
    
    if weather_json['cod'] == '404':
        print('City not found. Skipping...')
        continue 

    # Below assembles formatted json
    formatted_weath_json['City'] = weather_json['name']
    formatted_weath_json['Lat'] = weather_json['coord']['lat']
    formatted_weath_json['Lng'] = weather_json['coord']['lon']
    formatted_weath_json['Max Temp'] = weather_json['main']['temp_max']
    formatted_weath_json['Humidity'] = weather_json['main']['humidity']
    formatted_weath_json['Cloudiness'] = weather_json['clouds']['all']
    formatted_weath_json['Wind Speed'] = weather_json['wind']['speed']
    formatted_weath_json['Country'] = weather_json['sys']['country']
    formatted_weath_json['Date'] = weather_json['dt']
    

    # Are "sets" just a formatting thing or is it relevant for grouping?
        
    city_data.append(formatted_weath_json)
    print(f"Processing Record {counter} of Set {set_counter} |{weather_json['name']}")
# Out:
# Processing Record 1 of Set 1 |Abu Samrah
# Processing Record 2 of Set 1 |Kapaa
# Processing Record 3 of Set 1 |Mar del Plata
# Processing Record 4 of Set 1 |Dorokhovo
# Processing Record 5 of Set 1 |Coquimbo
# Processing Record 6 of Set 1 |Bluff
# Processing Record 7 of Set 1 |Butaritari
# Processing Record 8 of Set 1 |Rikitea
# Processing Record 9 of Set 1 |Bredasdorp
# Processing Record 10 of Set 1 |Xai-Xai
# City not found. Skipping...
# Processing Record 12 of Set 1 |Khatanga
# Processing Record 13 of Set 1 |Busselton
# Processing Record 14 of Set 1 |Lebu
# Processing Record 15 of Set 1 |Tibati
# Processing Record 16 of Set 1 |Barrow
# Processing Record 17 of Set 1 |Isangel
# Processing Record 18 of Set 1 |Anadyr
# Processing Record 19 of Set 1 |Mazara del Vallo
# Processing Record 20 of Set 1 |Ushuaia
# Processing Record 21 of Set 1 |Pokhara
# Processing Record 22 of Set 1 |Adrar
# Processing Record 23 of Set 1 |Puerto Ayora
# Processing Record 24 of Set 1 |Eston
# Processing Record 25 of Set 1 |Avarua
# Processing Record 26 of Set 1 |Atuona
# Processing Record 27 of Set 1 |The Valley
# Processing Record 28 of Set 1 |Tuatapere
# Processing Record 29 of Set 1 |San Cristobal
# Processing Record 30 of Set 1 |Kahului
# Processing Record 31 of Set 1 |Lieksa
# Processing Record 3 of Set 3 |Vaini
# Processing Record 4 of Set 3 |Klaksvík
# Processing Record 5 of Set 3 |Osečina
# Processing Record 6 of Set 3 |Tasiilaq
# Processing Record 7 of Set 3 |Saint-Pierre
# Processing Record 8 of Set 3 |Rawson
# City not found. Skipping...
# Processing Record 10 of Set 3 |Longyearbyen
# Processing Record 11 of Set 3 |Fortuna
# Processing Record 12 of Set 3 |Alice Springs
# Processing Record 13 of Set 3 |Geraldton
# Processing Record 14 of Set 3 |Chokurdakh
# Processing Record 15 of Set 3 |Punta Arenas
# Processing Record 16 of Set 3 |Yerbogachën
# Processing Record 17 of Set 3 |Deloraine
# City not found. Skipping...
# Processing Record 19 of Set 3 |Ust-Maya
# Processing Record 20 of Set 3 |Westport
# Processing Record 21 of Set 3 |Kupang
# Processing Record 22 of Set 3 |Kostomuksha
# Processing Record 23 of Set 3 |Ancud
# Processing Record 24 of Set 3 |Nouadhibou
# Processing Record 25 of Set 3 |Mergen
# Processing Record 26 of Set 3 |Saint George
# Processing Record 27 of Set 3 |Morón
# Processing Record 28 of Set 3 |Napier City
# Processing Record 29 of Set 3 |Scarborough
# Processing Record 30 of Set 3 |Gramsh
# Processing Record 31 of Set 3 |Ardakān
# Processing Record 32 of Set 3 |Dinard
# Processing Record 33 of Set 3 |Davila
# Processing Record 34 of Set 3 |Mari-Turek
# Processing Record 35 of Set 3 |Mount Isa
# Processing Record 36 of Set 3 |Hilo
# Processing Record 37 of Set 3 |San Policarpo
# Processing Record 38 of Set 3 |Flinders
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 3 |Faanui
# Processing Record 42 of Set 3 |Kutum
# Processing Record 43 of Set 3 |Muriwai Beach
# Processing Record 44 of Set 3 |Nabire
# Processing Record 45 of Set 3 |Banjarmasin
# Processing Record 46 of Set 3 |Bambous Virieux
# Processing Record 47 of Set 3 |Moindou
# Processing Record 48 of Set 3 |Baykit
# Processing Record 49 of Set 3 |San Luis
# Processing Record 50 of Set 3 |Pa Sang
# Processing Record 0 of Set 4 |Hithadhoo
# Processing Record 1 of Set 4 |Ürümqi
# Processing Record 2 of Set 4 |East London
# Processing Record 3 of Set 4 |Pangkalanbuun
# Processing Record 4 of Set 4 |Yamada
# City not found. Skipping...
# Processing Record 6 of Set 4 |Shelburne
# Processing Record 7 of Set 4 |Acajutla
# Processing Record 8 of Set 4 |Kloulklubed
# Processing Record 9 of Set 4 |Itarema
# Processing Record 10 of Set 4 |Maumere
# Processing Record 11 of Set 4 |Morondava
# Processing Record 12 of Set 4 |Jishou
# Processing Record 13 of Set 4 |Laas
# Processing Record 14 of Set 4 |Kaitangata
# Processing Record 15 of Set 4 |Gaoual
# Processing Record 16 of Set 4 |Mossamedes
# Processing Record 17 of Set 4 |Acapulco de Juárez
# Processing Record 18 of Set 4 |Cidreira
# Processing Record 19 of Set 4 |Pacora
# Processing Record 20 of Set 4 |Brønnøysund
# Processing Record 21 of Set 4 |Laguna
# Processing Record 22 of Set 4 |Fairbanks
# Processing Record 23 of Set 4 |Pingliang
# Processing Record 24 of Set 4 |Port Alfred
# Processing Record 25 of Set 4 |College
# Processing Record 26 of Set 4 |Mitsamiouli
# Processing Record 27 of Set 4 |Ossora
# Processing Record 28 of Set 4 |Carutapera
# Processing Record 29 of Set 4 |Amazar
# Processing Record 30 of Set 4 |Acaraú
# Processing Record 31 of Set 4 |Xichang
# Processing Record 32 of Set 4 |Beyneu
# Processing Record 33 of Set 4 |Porto-Novo
# Processing Record 34 of Set 4 |Saskylakh
# Processing Record 35 of Set 4 |Grand Gaube
# Processing Record 36 of Set 4 |Forsytheganj
# Processing Record 37 of Set 4 |Sampit
# Processing Record 38 of Set 4 |Onalaska
# Processing Record 39 of Set 4 |Kungurtug
# Processing Record 40 of Set 4 |Alugan
# Processing Record 41 of Set 4 |Vila Franca do Campo
# Processing Record 42 of Set 4 |Beroroha
# Processing Record 43 of Set 4 |Colares
# Processing Record 44 of Set 4 |Anloga
# Processing Record 45 of Set 4 |San Patricio
# Processing Record 46 of Set 4 |Lata
# Processing Record 47 of Set 4 |Valparaíso
# Processing Record 48 of Set 4 |Miandrivazo
# Processing Record 49 of Set 4 |Nizhneudinsk
# Processing Record 50 of Set 4 |Hong Kong
# Processing Record 0 of Set 5 |Saint-Augustin
# Processing Record 1 of Set 5 |Coyhaique
# Processing Record 2 of Set 5 |Soe
# Processing Record 3 of Set 5 |Onverwacht
# Processing Record 4 of Set 5 |Carnarvon
# Processing Record 5 of Set 5 |Turukhansk
# Processing Record 6 of Set 5 |La Tuque
# Processing Record 7 of Set 5 |Amoy
# City not found. Skipping...
# Processing Record 9 of Set 5 |Bathsheba
# Processing Record 10 of Set 5 |Zyryanka
# Processing Record 11 of Set 5 |Villa María
# Processing Record 12 of Set 5 |Concarneau
# Processing Record 13 of Set 5 |Ugoofaaru
# Processing Record 14 of Set 5 |St. George's
# Processing Record 15 of Set 5 |Saldanha
# Processing Record 16 of Set 5 |Alta Floresta
# Processing Record 17 of Set 5 |Faxinal
# Processing Record 18 of Set 5 |Xinmin
# Processing Record 19 of Set 5 |Banjar
# Processing Record 20 of Set 5 |Barra de Tecoanapa
# City not found. Skipping...
# Processing Record 22 of Set 5 |Tura
# Processing Record 23 of Set 5 |Cap Malheureux
# Processing Record 24 of Set 5 |Port Blair
# Processing Record 25 of Set 5 |Salitral
# Processing Record 26 of Set 5 |Sexsmith
# City not found. Skipping...
# Processing Record 28 of Set 5 |Kalmunai
# Processing Record 29 of Set 5 |Lorengau
# Processing Record 30 of Set 5 |Córdoba
# Processing Record 31 of Set 5 |Sisimiut
# Processing Record 32 of Set 5 |Baraboo
# Processing Record 33 of Set 5 |Khorixas
# Processing Record 34 of Set 5 |Jieshi
# Processing Record 35 of Set 5 |Marawi
# Processing Record 36 of Set 5 |Dhidhdhoo
# City not found. Skipping...
# Processing Record 38 of Set 5 |Ixtapa
# Processing Record 39 of Set 5 |Bushehr
# Processing Record 40 of Set 5 |Cherskiy
# Processing Record 41 of Set 5 |Aktau
# Processing Record 42 of Set 5 |Vuktyl
# Processing Record 43 of Set 5 |Xam Nua
# Processing Record 44 of Set 5 |Båtsfjord
# Processing Record 45 of Set 5 |Pevek
# City not found. Skipping...
# Processing Record 47 of Set 5 |Banepā
# Processing Record 48 of Set 5 |Oodweyne
# Processing Record 49 of Set 5 |Katsuura
# Processing Record 50 of Set 5 |Buckeye
# Processing Record 0 of Set 6 |Navrongo
# Processing Record 1 of Set 6 |Bandarbeyla
# Processing Record 2 of Set 6 |Gamba
# Processing Record 3 of Set 6 |Clyde River
# Processing Record 4 of Set 6 |Tombouctou
# Processing Record 5 of Set 6 |Castro
# Processing Record 6 of Set 6 |Paragould
# Processing Record 7 of Set 6 |Broken Hill
# Processing Record 8 of Set 6 |Talara
# Processing Record 9 of Set 6 |Huangmei
# Processing Record 10 of Set 6 |Kruisfontein
# Processing Record 11 of Set 6 |Severo-Kuril'sk
# Processing Record 12 of Set 6 |Inhuma
# Processing Record 13 of Set 6 |Leshukonskoye
# Processing Record 14 of Set 6 |Vila
# Processing Record 15 of Set 6 |Xique-Xique
# Processing Record 16 of Set 6 |General Roca
# Processing Record 17 of Set 6 |Vyartsilya
# Processing Record 18 of Set 6 |Athabasca
# Processing Record 19 of Set 6 |Dubno
# Processing Record 20 of Set 6 |Srednekolymsk
# Processing Record 21 of Set 6 |Rundu
# City not found. Skipping...
# Processing Record 23 of Set 6 |Sirte
# Processing Record 24 of Set 6 |Quatre Cocos
# Processing Record 25 of Set 6 |Bukama
# Processing Record 26 of Set 6 |Ostrovnoy
# Processing Record 27 of Set 6 |Douala
# City not found. Skipping...
# Processing Record 29 of Set 6 |Sørland
# Processing Record 30 of Set 6 |Salalah
# Processing Record 31 of Set 6 |Stornoway
# Processing Record 32 of Set 6 |Camacha
# Processing Record 33 of Set 6 |Zyryanovsk
# Processing Record 34 of Set 6 |Ulladulla
# Processing Record 35 of Set 6 |Ukiah
# Processing Record 36 of Set 6 |Vung Tau
# Processing Record 37 of Set 6 |Brae
# Processing Record 38 of Set 6 |Iberia
# Processing Record 39 of Set 6 |Port Elizabeth
# Processing Record 40 of Set 6 |Seoul
# City not found. Skipping...
# Processing Record 42 of Set 6 |Assiut
# Processing Record 43 of Set 6 |Garden City
# Processing Record 44 of Set 6 |Otjimbingwe
# Processing Record 45 of Set 6 |Masterton
# Processing Record 46 of Set 6 |Codrington
# Processing Record 47 of Set 6 |Normandin
# Processing Record 48 of Set 6 |Cascais
# Processing Record 49 of Set 6 |Havre-St-Pierre
# Processing Record 50 of Set 6 |Haines Junction
# Processing Record 0 of Set 7 |Sola
# Processing Record 1 of Set 7 |Slonim
# Processing Record 2 of Set 7 |Ilulissat
# Processing Record 3 of Set 7 |Neryungri
# Processing Record 4 of Set 7 |Hat Yai
# Processing Record 5 of Set 7 |Taltal
# Processing Record 6 of Set 7 |San Quintín
# Processing Record 7 of Set 7 |Bodden Town
# Processing Record 8 of Set 7 |Dalby
# City not found. Skipping...
# Processing Record 10 of Set 7 |Yeppoon
# Processing Record 11 of Set 7 |Lerum
# Processing Record 12 of Set 7 |Kerman
# Processing Record 13 of Set 7 |Vanimo
# Processing Record 14 of Set 7 |Chiang Khong
# Processing Record 15 of Set 7 |Pemangkat
# Processing Record 16 of Set 7 |Padang
# Processing Record 17 of Set 7 |Peniche
# Processing Record 44 of Set 8 |Lunenburg
# Processing Record 45 of Set 8 |Beira
# Processing Record 46 of Set 8 |Rudnyy
# Processing Record 47 of Set 8 |Kaniama
# Processing Record 48 of Set 8 |Vestmannaeyjar
# Processing Record 49 of Set 8 |Atikokan
# Processing Record 50 of Set 8 |Marabu
# Processing Record 0 of Set 9 |Cockburn Town
# Processing Record 1 of Set 9 |Anekal
# Processing Record 2 of Set 9 |Puerto Lleras
# Processing Record 3 of Set 9 |Bertoua
# Processing Record 4 of Set 9 |Lagos
# Processing Record 5 of Set 9 |Yar-Sale
# Processing Record 6 of Set 9 |Port Angeles
# Processing Record 7 of Set 9 |Abu Dhabi
# Processing Record 8 of Set 9 |Nikolskoye
# City not found. Skipping...
# Processing Record 10 of Set 9 |Malinovskiy
# Processing Record 11 of Set 9 |Lao Cai
# Processing Record 12 of Set 9 |Kulykivka
# Processing Record 13 of Set 9 |Olutanga
# Processing Record 14 of Set 9 |Hirara
# City not found. Skipping...
# Processing Record 16 of Set 9 |Yichang
# Processing Record 17 of Set 9 |Ntoum
# Processing Record 18 of Set 9 |La Palma del Condado
# Processing Record 19 of Set 9 |Nioro
# Processing Record 20 of Set 9 |Thinadhoo
# Processing Record 21 of Set 9 |Jaqué
# Processing Record 22 of Set 9 |Stephenville
# Processing Record 23 of Set 9 |Bara
# Processing Record 24 of Set 9 |Portel
# Processing Record 25 of Set 9 |Aquiraz
# Processing Record 26 of Set 9 |Caucayá
# Processing Record 27 of Set 9 |Kiunga
# Processing Record 28 of Set 9 |Māngrol
# Processing Record 29 of Set 9 |Boone
# Processing Record 30 of Set 9 |Antofagasta
# City not found. Skipping...
# Processing Record 32 of Set 9 |Harlingen
# Processing Record 33 of Set 9 |Darnah
# Processing Record 34 of Set 9 |Thouars
# Processing Record 35 of Set 9 |Pescia
# Processing Record 36 of Set 9 |Cañete
# Processing Record 37 of Set 9 |Lund
# Processing Record 38 of Set 9 |West Des Moines
# Processing Record 39 of Set 9 |Douentza
# Processing Record 40 of Set 9 |Puerto del Rosario
# Processing Record 41 of Set 9 |Ojinaga
# Processing Record 42 of Set 9 |Stodolishche
# Processing Record 43 of Set 9 |Taoudenni
# Processing Record 44 of Set 9 |Camaçari
# Processing Record 45 of Set 9 |Kiryat Gat
# Processing Record 46 of Set 9 |Uglich
# Processing Record 47 of Set 9 |Smalininkai
# Processing Record 48 of Set 9 |Ketchikan
# Processing Record 49 of Set 9 |Rabat
# Processing Record 50 of Set 9 |Tynda
# Processing Record 0 of Set 10 |Sengiley
# Processing Record 1 of Set 10 |Fort Nelson
# Processing Record 2 of Set 10 |Vallenar
# City not found. Skipping...
# Processing Record 4 of Set 10 |Cururupu
# Processing Record 5 of Set 10 |Marsabit
# Processing Record 6 of Set 10 |Olafsvik
# Processing Record 7 of Set 10 |Sfântu Gheorghe
# City not found. Skipping...
# Processing Record 9 of Set 10 |Qui Nhon
# Processing Record 10 of Set 10 |Boa Vista
# Processing Record 11 of Set 10 |Kumluca
# Processing Record 12 of Set 10 |Mahuta
# Processing Record 13 of Set 10 |Moussoro
# Processing Record 37 of Set 11 |Kotel'nich
# Processing Record 38 of Set 11 |Dauriya
# Processing Record 39 of Set 11 |Ştefan Vodă
# Processing Record 40 of Set 11 |Vytegra
# Processing Record 41 of Set 11 |Mahébourg
# Processing Record 42 of Set 11 |Hualmay
# Processing Record 43 of Set 11 |Kyrenia
# Processing Record 44 of Set 11 |Talnakh
# Processing Record 45 of Set 11 |Kars
# Processing Record 46 of Set 11 |Mbanza-Ngungu
# Processing Record 47 of Set 11 |Cairns
# Processing Record 48 of Set 11 |Kishanpur
# Processing Record 49 of Set 11 |Doctor Arroyo
# Processing Record 50 of Set 11 |Montrose
# Processing Record 0 of Set 12 |Forio
# Processing Record 1 of Set 12 |Carberry
# Processing Record 2 of Set 12 |Bandar
# Processing Record 3 of Set 12 |Catuday
# Processing Record 4 of Set 12 |Grand-Santi
# Processing Record 5 of Set 12 |Marsh Harbour
# Processing Record 6 of Set 12 |Chernyshevskiy
# Processing Record 7 of Set 12 |Port Hardy
# Processing Record 8 of Set 12 |Santiago del Estero
# Processing Record 9 of Set 12 |La Bélgica
# Processing Record 10 of Set 12 |Jinxiang
# Processing Record 11 of Set 12 |Shangzhi
# Processing Record 12 of Set 12 |Challakere
# Processing Record 13 of Set 12 |Birao
# Processing Record 14 of Set 12 |Tuscaloosa
# Processing Record 15 of Set 12 |Paamiut
# Processing Record 16 of Set 12 |Pitimbu
# Processing Record 17 of Set 12 |Mouzourás
# Processing Record 18 of Set 12 |Dakar
# Processing Record 19 of Set 12 |Guerrero Negro
# Processing Record 20 of Set 12 |Torres
# Processing Record 21 of Set 12 |Sangar
# City not found. Skipping...
# Processing Record 23 of Set 12 |Krasnosel'kup
# Processing Record 24 of Set 12 |Ulaangom
# Processing Record 25 of Set 12 |Luanda
# Processing Record 26 of Set 12 |Senador José Porfírio
# Processing Record 27 of Set 12 |Sindor
# Processing Record 28 of Set 12 |Florianópolis
# Processing Record 29 of Set 12 |Kenora
# Processing Record 30 of Set 12 |Pisco
# Processing Record 31 of Set 12 |Baghdad
# Processing Record 32 of Set 12 |Idenao
# Processing Record 33 of Set 12 |Sicuani
# Processing Record 34 of Set 12 |Trincomalee
# Processing Record 35 of Set 12 |Corinth
# Processing Record 36 of Set 12 |Dalmatovo
# Processing Record 37 of Set 12 |Tamiahua
# Processing Record 38 of Set 12 |Orbetello
# Processing Record 39 of Set 12 |Murgab
# Processing Record 40 of Set 12 |Zaraza
# City not found. Skipping...
# Processing Record 42 of Set 12 |Umm Kaddadah
# City not found. Skipping...
# Processing Record 44 of Set 12 |Salamiyah
# Processing Record 45 of Set 12 |Saint-Joseph
# Processing Record 46 of Set 12 |Juba
# Processing Record 47 of Set 12 |Kathmandu
# Processing Record 48 of Set 12 |Hudiksvall
# Processing Record 49 of Set 12 |Bilma
# Processing Record 50 of Set 12 |Chitipa
# Processing Record 0 of Set 13 |Prince Rupert
# Processing Record 1 of Set 13 |Beihai
# Processing Record 2 of Set 13 |Dingle
# Processing Record 3 of Set 13 |Escanaba
# Processing Record 4 of Set 13 |Jumla
# Processing Record 5 of Set 13 |Nsunga
# Processing Record 6 of Set 13 |Solnechnyy

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# converting json dataset from dictionary to dataframe
city_dataframe = pd.DataFrame.from_dict(json_normalize(city_data), orient='columns')

city_dataframe.count()
# Out:
# C:\Users\asiah\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# City          575
# Lat           575
# Lng           575
# Max Temp      575
# Humidity      575
# Cloudiness    575
# Wind Speed    575
# Country       575
# Date          575
# dtype: int64

# %%
city_dataframe.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Abu Samrah  35.30   37.18    297.54        47           0        5.55
# 1          Kapaa  22.08 -159.32    299.15        78          40        6.70
# 2  Mar del Plata -38.00  -57.56    287.15        30           0        9.80
# 3      Dorokhovo  55.55   36.37    292.15        59           5        3.00
# 4       Coquimbo -29.95  -71.34    284.15        81          90        2.10
#
#   Country        Date
# 0      SY  1597686414
# 1      US  1597686414
# 2      AR  1597686415
# 3      RU  1597686415
# 4      CL  1597686418

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
 city_dataframe.loc[city_dataframe['Humidity'] >100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# N/A

# %%
# Extract relevant fields from the data frame

city_dataframe.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  575.000000  575.000000  575.000000  575.000000  575.000000  575.000000
# mean    19.123861   17.488452  294.386974   69.060870   48.556522    3.465687
# std     33.072870   88.992315    8.429293   20.933313   36.481963    2.304374
# min    -54.800000 -175.200000  274.150000    5.000000    0.000000    0.150000
# 25%     -7.400000  -63.230000  287.290000   58.000000    9.000000    1.670000
# 50%     21.480000   20.040000  296.300000   74.000000   47.000000    3.100000
# 75%     47.550000   99.390000  300.150000   84.000000   76.500000    4.615000
# max     78.220000  178.420000  318.520000  100.000000  100.000000   15.680000
#
#                Date
# count  5.750000e+02
# mean   1.597687e+09
# std    1.149691e+02
# min    1.597686e+09
# 25%    1.597686e+09
# 50%    1.597687e+09
# 75%    1.597687e+09
# max    1.597687e+09

# %%
# Export the City_Data into a csv

city_dataframe.to_csv('city_dataframe.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_temp_scatter = pd.read_csv('city_dataframe.csv')
lat_temp_scatter

# Ask about the scatterplot outliers and wheather I need format my ticker spacing

x = lat_temp_scatter["Lat"]
y = (lat_temp_scatter["Max Temp"] - 273.15) * 9/5 + 32 

plt.xlabel('Latitude'); plt.ylabel('Max Temperature (F)')

plt.scatter(x, y, marker="o", facecolors="steelblue", edgecolors="black",
            s=30, alpha=1)
plt.grid(b=True, which='major')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x = lat_temp_scatter["Lat"]
y = lat_temp_scatter["Humidity"] 

plt.xlabel('Latitude'); plt.ylabel('Humidity (%)')

plt.scatter(x, y, marker="o", facecolors="steelblue", edgecolors="black",
            s=30, alpha=1)
plt.grid(b=True, which='major')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x = lat_temp_scatter["Lat"]
y = lat_temp_scatter["Cloudiness"] 

plt.xlabel('Latitude'); plt.ylabel('Cloudiness (%)')

plt.scatter(x, y, marker="o", facecolors="steelblue", edgecolors="black",
            s=30, alpha=1)
plt.grid(b=True, which='major')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x = lat_temp_scatter["Lat"]
y = lat_temp_scatter["Wind Speed"] 

plt.xlabel('Latitude'); plt.ylabel('Wind Speed (mph)')


plt.scatter(x, y, marker="o", facecolors="steelblue", edgecolors="black",
            s=30, alpha=1)
plt.grid(b=True, which='major')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# Want it to work for anything input into the function

def hemi_split(hemisphere_data, latitude):
    if latitude == 'north':
        return hemisphere_data.loc[hemisphere_data['Lat'] > 0]
    elif latitude == 'south':
        return hemisphere_data.loc[hemisphere_data['Lat'] < 0]
    else:
        return print("Please input north or south")
#     x = np.array([hemi_split][north])
#     y = np.array([10.35,12.3,13,14.0,16,17,18.2,20,20.7,22.5])
#     gradient, intercept, r_value, p_value, std_err = stats.linregress(x,y)
#     mn=np.min(x)
#     mx=np.max(x)
#     x1=np.linspace(mn,mx,500)
#     y1=gradient*x1+intercept

# hemi_split(city_dataframe, 'north')

# %%
# Create Northern and Southern Hemisphere DataFrames
# Dataframe is a dataset, running a linear regression, and retrieving metrics from it.
# Latitude runs north and south of the equator
# Use a .loc to filter your latitude
# Think, "What am I trying to do", psudo code it. 
# I have a dataframe of data with lats and lons
# split into north and south
# How do I split the coords
# How do I create a function for linear regression

# n_hemisphere = city_dataframe.loc[city_dataframe['Lat'] > 0]
# s_hemisphere = city_dataframe.loc[city_dataframe['Lat'] < 0]


# def hemi_split(hemisphere_data, latitude):
#     if latitude == 'north':
#         return hemisphere_data.loc[hemisphere_data['Lat'] > 0]
#     elif latitude == 'south':
#         return hemisphere_data.loc[hemisphere_data['Lat'] < 0]
#     else:
#         return print("Please input North or South")

south = hemi_split(city_dataframe, 'south')
north = hemi_split(city_dataframe, 'north')

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = np.array(north['Lat'])
y = np.array((north['Max Temp'] - 273.15) * 9/5 + 32)
gradient, intercept, r_value, p_value, std_err = linregress(x,y)
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title(f"Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
mn=np.min(x)
mx=np.max(x)
x1=np.linspace(mn,mx,500)
y1=gradient*x1+intercept
plt.plot(x,y,'ob')
plt.plot(x1,y1,'-r')
plt.savefig('Northern Max Temp v Latitude Linear Regression')
plt.show()

# Plot is showing that the decrease in max temperature is due to the increase in the latitidinal position of the city.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = np.array(south['Lat'])
y = np.array((south['Max Temp'] - 273.15) * 9/5 + 32)
gradient, intercept, r_value, p_value, std_err = linregress(x,y)
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title(f"Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
mn=np.min(x)
mx=np.max(x)
x1=np.linspace(mn,mx,500)
y1=gradient*x1+intercept
plt.plot(x,y,'ob')
plt.plot(x1,y1,'-r')
plt.savefig('Southern Max Temp v Latitude Linear Regression')
plt.show()

# Plot is showing that as the latitude of a city increases, so does the max temp.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = np.array(north['Lat'])
y = np.array(north['Humidity'])
gradient, intercept, r_value, p_value, std_err = linregress(x,y)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f"Northern Hemisphere - Humidity vs. Latitude Linear Regression")
mn=np.min(x)
mx=np.max(x)
x1=np.linspace(mn,mx,500)
y1=gradient*x1+intercept
plt.plot(x,y,'ob')
plt.plot(x1,y1,'-r')
plt.savefig('Northern Hemisphere Humidity v Latitude Linear Regression')
plt.show()

# Humidity is not determinied by the latidudinal location of the city. It seems there is little to no correlation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = np.array(south['Lat'])
y = np.array(south['Humidity'])
gradient, intercept, r_value, p_value, std_err = linregress(x,y)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f"Southern Hemisphere - Humidity vs. Latitude Linear Regression")
mn=np.min(x)
mx=np.max(x)
x1=np.linspace(mn,mx,500)
y1=gradient*x1+intercept
plt.plot(x,y,'ob')
plt.plot(x1,y1,'-r')
plt.savefig('Southern Hemisphere Humidity v Latitude Linear Regression')
plt.show()

# Humidity among cities in the Southern hemisphere seem scattered but decreasing in humidity overall.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = np.array(north['Lat'])
y = np.array(north['Cloudiness'])
gradient, intercept, r_value, p_value, std_err = linregress(x,y)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")
mn=np.min(x)
mx=np.max(x)
x1=np.linspace(mn,mx,500)
y1=gradient*x1+intercept
plt.plot(x,y,'ob')
plt.plot(x1,y1,'-r')
plt.savefig('Northern Hemisphere Cloudiness v Latitude Linear Regression')
plt.show()

# Cloud coverage is not determined by the latitudinal position of the city.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = np.array(south['Lat'])
y = np.array(south['Cloudiness'])
gradient, intercept, r_value, p_value, std_err = linregress(x,y)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")
mn=np.min(x)
mx=np.max(x)
x1=np.linspace(mn,mx,500)
y1=gradient*x1+intercept
plt.plot(x,y,'ob')
plt.plot(x1,y1,'-r')
plt.savefig('Southern Hemisphere Cloudiness v Latitude Linear Regression')
plt.show()

# Cloud coverage in the Southern hemisphere, like humidity, is more scattered but is decreasing.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = np.array(north['Lat'])
y = np.array(north['Wind Speed'])
gradient, intercept, r_value, p_value, std_err = linregress(x,y)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f"Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")
mn=np.min(x)
mx=np.max(x)
x1=np.linspace(mn,mx,500)
y1=gradient*x1+intercept
plt.plot(x,y,'ob')
plt.plot(x1,y1,'-r')
plt.savefig('Northern Hemisphere Wind Speed v Latitude Linear Regression')
plt.show()

# Not much correlation in wind speed and city location, slight increase as they grow more Northbound but not much.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = np.array(south['Lat'])
y = np.array(south['Wind Speed'])
gradient, intercept, r_value, p_value, std_err = linregress(x,y)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f"Southern Hemisphere - Wind Speed vs. Latitude Linear Regression")
mn=np.min(x)
mx=np.max(x)
x1=np.linspace(mn,mx,500)
y1=gradient*x1+intercept
plt.plot(x,y,'ob')
plt.plot(x1,y1,'-r')
plt.savefig('Southern Hemisphere Wind Speed v Latitude Linear Regression')
plt.show()

# Overall decrease in wind speed moving Northbound in the Southern hemisphere.
